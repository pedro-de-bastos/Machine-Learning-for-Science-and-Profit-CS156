# %% [markdown]
# <a href="https://colab.research.google.com/github/pedro-de-bastos/cs156/blob/master/CS112_4_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Part 1

# %%
library(Matching)
library(boot)
data(lalonde)

boot.fn <- function(data, index) return()
# Out:
# $call
# cv.glm(data = lalonde, glmfit = glm.lalonde)
#
# $K
# [1] 445
#
# $delta
# [1] 44047647 44044498
#
# $seed
#   [1]       10403          20   974437390   348759561   667188359   989483848
#   [7] -1094686321  1228508824 -1772960716  -912188049   823408948  -392126381
#  [13]   324289617   309822874   589750449   653353502  1125121250   616103293
#  [19]  1302191130 -1927716419 -1385584189  1329109828  1526930331 -2090954332
#  [25]   770601224  1682710835  1264768888  1485816719  1058241701 -1400264850
#  [31]  -471583739   457693682 -1019919746  1707667993  -933153434  1054230465
#  [37]  1437103823  1630471632  -808619609  -297837552  1053049292   418287351
#  [43] -1893008580  1205492683   620036329  1157002242  -171139415   -93140618
#  [49]  1640126986 -2122633083   755329890  1875078341 -1264678245 -1696397252
#  [55] -1896756029  -133027412  -887908208  -675601173 -1877626160  1619623560
#  [61]  1045660706  -840562340  1137594761   223459723  -382366425  2120836109
# ...
